# %%
import requests

url = 'https://www.virustotal.com/vtapi/v2/file/report'

params = {'apikey': '96dc3a2a477017c14100df82fed8074731478784480917540bb1318886fd0054', 'resource': 'e4e5c3a6c15beff4e17117075e2c0bd65f176d81e6885134d2b4d97c20d4773a'}

response = requests.get(url, params=params)

print(response.json())
# Out:
# {'scans': {'Bkav': {'detected': True, 'version': '1.3.0.9899', 'result': 'W32.AIDetectNet.01', 'update': '20230409'}, 'Lionic': {'detected': True, 'version': '7.5', 'result': 'Trojan.MSIL.Agensla.i!c', 'update': '20230409'}, 'Elastic': {'detected': True, 'version': '4.0.84', 'result': 'malicious (high confidence)', 'update': '20230406'}, 'DrWeb': {'detected': True, 'version': '7.0.59.12300', 'result': 'Trojan.Inject3.36400', 'update': '20230409'}, 'MicroWorld-eScan': {'detected': True, 'version': '14.0.409.0', 'result': 'Trojan.GenericKDZ.65577', 'update': '20230409'}, 'FireEye': {'detected': True, 'version': '35.24.1.0', 'result': 'Generic.mg.76fffeef410bd6b6', 'update': '20230409'}, 'CAT-QuickHeal': {'detected': True, 'version': '22.00', 'result': 'Trojan.YakbeexMSIL.ZZ4', 'update': '20230408'}, 'McAfee': {'detected': True, 'version': '6.0.6.653', 'result': 'GenericRXKA-OZ!76FFFEEF410B', 'update': '20230409'}, 'Malwarebytes': {'detected': True, 'version': '4.5.5.54', 'result': 'Tro
# ...

# %%
import requests
mhash="e4e5c3a6c15beff4e17117075e2c0bd65f176d81e6885134d2b4d97c20d4773a"
urlh = "https://www.virustotal.com/api/v3/files/"
url=urlh+mhash
print(url)
headers = {
    "accept": "application/json",
    "x-apikey": "96dc3a2a477017c14100df82fed8074731478784480917540bb1318886fd0054"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# https://www.virustotal.com/api/v3/files/e4e5c3a6c15beff4e17117075e2c0bd65f176d81e6885134d2b4d97c20d4773a
# {
#     "data": {
#         "attributes": {
#             "type_description": "Win32 EXE",
#             "tlsh": "T125841206769ECB3BD87D17F9A5C3020093B746811B53DB7E9CC691DA2C7A3490762E8B",
#             "vhash": "235036751512a010221162041",
#             "type_tags": [
#                 "executable",
#                 "windows",
#                 "win32",
#                 "pe",
#                 "peexe"
#             ],
#             "signature_info": {
#                 "product": "MathClasses",
#                 "internal name": "LPcXtrWBQgADzEqI.exe",
#                 "copyright": "Copyright \u00a9  2016 - 2020",
#                 "original name": "LPcXtrWBQgADzEqI.exe",
#                 "file version": "3.0.4.2",
#                 "description": "MathClasses"
#             },
#             "creation_date": 1584514775,
#             "names": [
# ...
